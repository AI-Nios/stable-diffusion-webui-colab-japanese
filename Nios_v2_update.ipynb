# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-Nios/stable-diffusion-webui-colab-japanese/blob/main/Nios_v2_update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 1.WebUIのインストール
#パッケージインストール
# !pip install -q https://github.com/camenduru/stable-diffusion-webui-colab/releases/download/0.0.17/xformers-0.0.17+b6be33a.d20230315-cp39-cp39-linux_x86_64.whl
# !pip install -q --pre triton
#WebUIのインストール
# !git clone -b v2.0 https://github.com/camenduru/stable-diffusion-webui
#超便利なExtensions
# !git clone https://github.com/alemelis/sd-webui-ar.git /content/stable-diffusion-webui/extensions/sd-webui-ar
# !git clone https://github.com/yfszzx/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
# !git clone https://github.com/camenduru/stable-diffusion-webui-huggingface /content/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git /content/stable-diffusion-webui/extensions/a1111-sd-webui-tagcomplete
#WebUIの拡張機能(Extensions)
Extensions = True #@param {'type':'boolean'}
if Extensions == True :
  # !git clone https://github.com/toshiaki1729/stable-diffusion-webui-dataset-tag-editor.git /content/stable-diffusion-webui/extensions/dataset-tag-editor
  # !git clone https://github.com/bbc-mc/sdweb-merge-block-weighted-gui /content/stable-diffusion-webui/extensions/sdweb-merge-block-weighted-gui
  # !git clone -b v2.0 https://github.com/camenduru/sd-civitai-browser /content/stable-diffusion-webui/extensions/sd-civitai-browser
  # !git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/stable-diffusion-webui/extensions/sd-webui-additional-networks
  # !git clone https://github.com/opparco/stable-diffusion-webui-two-shot.git /content/stable-diffusion-webui/extensions/stable-diffusion-webui-two-shot
  # !git apply --ignore-whitespace /extensions/stable-diffusion-webui-two-shot/cfg_denoised_callback-ea9bd9fc.patch
  # !git clone https://github.com/hallatore/stable-diffusion-webui-chatgpt-utilities /content/stable-diffusion-webui/extensions/stable-diffusion-webui-chatgpt-utilities
  # !git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-locon.git /content/stable-diffusion-webui/extensions/a1111-sd-webui-locon

ControlNet = True #@param {'type':'boolean'}
if ControlNet == True :
  # !git clone https://github.com/camenduru/openpose-editor /content/stable-diffusion-webui/extensions/openpose-editor
  # !git clone https://github.com/Mikubill/sd-webui-controlnet.git /content/stable-diffusion-webui/extensions/sd-webui-controlnet
  # !git clone https://github.com/jexom/sd-webui-depth-lib /content/stable-diffusion-webui/extensions/sd-webui-depth-lib
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_canny-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_depth-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_hed-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_mlsd-fp16.safetensorss
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_normal-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_openpose-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_scribble-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_seg-fp16.safetensors

# %cd /content/stable-diffusion-webui
#EasyNegative
# !wget https://huggingface.co/datasets/gsdf/EasyNegative/resolve/main/EasyNegative.pt -O /content/stable-diffusion-webui/embeddings/EasyNegative.pt

# %%
#@title  2.モデル選択
#@markdown モデルを選択してから実行してください。

model_name ="Counterfeit-V2.5" #@param ["stable_diffusion_v1.5","stable_diffusion_v2.1","waifu_diffusion_v1.3","Openjourney","anything-v3.0","anything-v4.0","anything-v4.5","Counterfeit-V2.0","Counterfeit-V2.5","8528-diffusion","AbyssOrangeMix2","EerieOrangeMix2","trinart2_step115000","Eimis Anime Diffusion_1.0v","dreamlike-photoreal-2.0","Cyberpunk-Anime-Diffusion","Plat Diffusion v1.3.1","ACertainThing","pastel_mix","Basil_mix_fixed","Realistic Vision V1.3","SukiyakiMix-v1.0","7th_anime_v1.1", "7th_anime_v2_A", "7th_anime_v2_B", "7th_anime_v2_C", "7th_anime_v2_G", "7th_anime_v3_A", "7th_anime_v3_B", "7th_anime_v3_C","7th_anime_3.1_B","YuzuGinger_v4","YuzuLemonMilk_v1.5", "Defmix-v1.1","RDtMix","meadmix","Nabylon-v1.0","LonganMix","Corneo's 7th Heaven Mix", "Corneo's Shinra26 Mix","atwmix_test2","Graham_Special","ACertainModel","BalorV2featAbyssOrange2","Balor-V2.5featAOM3A3","ChilloutMix","wd-1-5-beta2"] {allow-input: false}
if model_name == "stable_diffusion_v1.5":
  url1  = "https://huggingface.co/camenduru/sd15/resolve/main/v1-5-pruned-emaonly.ckpt"
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/v1-5-pruned-emaonly.ckpt"

elif model_name == "stable_diffusion_v2.1":
  url1  = "https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.ckpt" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/v2-1_768-ema-pruned.ckpt"

elif model_name == "waifu_diffusion_v1.3":
  url1  = "https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/wd-v1-3-float32.ckpt"

elif model_name == "Openjourney":
  url1  = "https://huggingface.co/prompthero/openjourney/resolve/main/mdjrny-v4.safetensors"
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/mdjrny-v4.safetensors"

elif model_name == "anything-v3.0":
  url1  = "https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/anything-v3-fp32-pruned.safetensors"
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/anything-v3-fp32-pruned.safetensors"
  
elif model_name == "anything-v4.0":
  url1  = "https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned.ckpt"
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/anything-v4.0-pruned.ckpt"

elif model_name == "anything-v4.5":
  url1  = "https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/anything-v4.5-pruned.safetensors"

elif model_name == "Counterfeit-V2.0":
  url1  = "https://huggingface.co/gsdf/Counterfeit-V2.0/resolve/main/Counterfeit-V2.0fp16.safetensors"
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Counterfeit-V2.0fp16.safetensors"

elif model_name == "Counterfeit-V2.5":
  url1  = "https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5_pruned.safetensors"
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Counterfeit-V2.5_pruned.safetensors"

elif model_name == "8528-diffusion":
  url1  = "https://huggingface.co/852wa/8528-diffusion/resolve/main/8528d-final.ckpt"
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/8528d-final.ckpt"

elif model_name == "AbyssOrangeMix2":
  url1  = "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_nsfw.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/AbyssOrangeMix2_sfw.safetensors"

elif model_name == "EerieOrangeMix2":
  url1  = "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/EerieOrangeMix/EerieOrangeMix2.safetensors " 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/EerieOrangeMix2.safetensors"

elif model_name == "trinart2_step115000":
  url1  = "https://huggingface.co/naclbit/trinart_stable_diffusion_v2/resolve/main/trinart2_step115000.ckpt " 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/trinart2_step115000.ckpt"

elif model_name == "Eimis Anime Diffusion_1.0v":
  url1  = "https://huggingface.co/eimiss/EimisAnimeDiffusion_1.0v/resolve/main/EimisAnimeDiffusion_1-0v.ckpt " 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/EimisAnimeDiffusion_1-0v.ckpt"

elif model_name == "dreamlike-photoreal-2.0":
  url1  = "https://huggingface.co/dreamlike-art/dreamlike-photoreal-2.0/resolve/main/dreamlike-photoreal-2.0.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/dreamlike-photoreal-2.0.safetensors"

elif model_name == "Cyberpunk-Anime-Diffusion":
  url1  = "https://huggingface.co/DGSpitzer/Cyberpunk-Anime-Diffusion/resolve/main/Cyberpunk-Anime-Diffusion.ckpt" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Cyberpunk-Anime-Diffusion.ckpt"

elif model_name == "Plat Diffusion v1.3.1":
  url1  = "https://huggingface.co/p1atdev/pd-archive/resolve/main/plat-v1-3-1.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/plat-v1-3-1.safetensors"

elif model_name == "ACertainThing":
  url1  = "https://huggingface.co/JosephusCheung/ACertainThing/resolve/main/ACertainThing.ckpt" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/ACertainThing.ckpt"

elif model_name == "pastel_mix":
  url1  = "https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-better-vae-fp32.ckpt" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/pastel_mix.ckpt"

elif model_name == "Basil_mix_fixed":
  url1  = "https://huggingface.co/nuigurumi/basil_mix/resolve/main/Basil_mix_fixed.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Basil_mix_fixed.safetensors"

elif model_name == "Realistic Vision V1.3":
  url1  = "https://civitai.com/api/download/models/6987" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Realistic_Vision.safetensors"

elif model_name == "SukiyakiMix-v1.0":
  url1  = "https://huggingface.co/Vsukiyaki/SukiyakiMix-v1.0/resolve/main/SukiyakiMix-v1.0-fp16.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/SukiyakiMix-v1.0-fp16.safetensors"
  url2  = "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt"
  path2 = "/content/stable-diffusion-webui/models/Stable-diffusion/Basil_mix_fixed.vae.pt"

elif model_name == "7th_anime_v1.1":
  url1  = "https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v1/7th_anime_v1.1.safetensors"
  path1  = "/content/stable-diffusion-webui/models/Stable-diffusion/7th_anime_v1.1.safetensors"

elif model_name == "7th_anime_v2_A":
  url1  = "https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_A.safetensors"
  path1  = "/content/stable-diffusion-webui/models/Stable-diffusion/7th_anime_v2_A.safetensors"

elif model_name == "7th_anime_v2_B":
  url1  = "https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_B.safetensors"
  path1  = "/content/stable-diffusion-webui/models/Stable-diffusion/7th_anime_v2_B.safetensors"

elif model_name == "7th_anime_v2_C":
  url1  = "https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_C.safetensors"
  path1  = "/content/stable-diffusion-webui/models/Stable-diffusion/7th_anime_v2_C.safetensors"

elif model_name == "7th_anime_v2_G":
  url1  = "https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_G.safetensors"
  path1  = "/content/stable-diffusion-webui/models/Stable-diffusion/7th_anime_v2_G.safetensors"
  
elif model_name == "7th_anime_v3_A":
  url1  = "https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_A.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/7th_anime_v3_A.safetensors"

elif model_name == "7th_anime_v3_B":
  url1  = "https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_B.safetensors"
  path1  = "/content/stable-diffusion-webui/models/Stable-diffusion/7th_anime_v3_B.safetensors"

elif model_name == "7th_anime_v3_C":
  url1  = "https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_C.safetensors"
  path1  = "/content/stable-diffusion-webui/models/Stable-diffusion/7th_anime_v3_C.safetensors"

elif model_name == "7th_anime_3.1_B":
  url1  = "https://huggingface.co/syaimu/7th_test/resolve/main/7th_anime_3.1_B.ckpt" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/7th_anime_3.1_B.ckpt"

elif model_name == "YuzuGinger_v4":
  url1  = "https://huggingface.co/thiros/YuzuLemonTea/resolve/main/YuzuGinger_v4-pruned.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/YuzuGinger_v4-pruned.safetensors"

elif model_name == "YuzuLemonMilk_v1.5":
  url1  = "https://huggingface.co/thiros/YuzuLemonTea/resolve/main/YuzuLemonMilk_v1.5-pruned.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/YuzuLemonMilk_v1.5-pruned.safetensors"

elif model_name == "Defmix-v1.1":
  url1  = "https://huggingface.co/Defpoint/Defmix-v1.0/resolve/main/Defmix-v1.1.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Defmix-v1.1.safetensors"

elif model_name == "RDtMix":
  url1  = "https://huggingface.co/Hemlok/DateMix/resolve/main/RDtMix-fp16.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Defmix-fictio.safetensors"

elif model_name == "meadmix":
  url1  = "https://huggingface.co/sazanka-imoto/MeadMix/resolve/main/meadmix.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/meadmix.safetensors"

elif model_name == "Nabylon-v1.0":
  url1  = "https://huggingface.co/NegiInNattoMaki/Nabylon-v1.0/resolve/main/Nabylon-v1.0-fp16.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Nabylon-v1.0-fp16.safetensors"

elif model_name == "LonganMix":
  url1  = "https://huggingface.co/Hemlok/LonganMix/resolve/main/LonganMix-fp16.ckpt" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/LonganMix-fp16.ckpt" 

elif model_name == "Corneo's 7th Heaven Mix":
  url1  = "https://civitai.com/api/download/models/5338" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Corneos_7th_Heaven_Mix.safetensors"

elif model_name == "Corneo's Shinra26 Mix":
  url1  = "https://civitai.com/api/download/models/6918" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Corneos_Shinra26_Mix.safetensors"

elif model_name == "atwmix_test2":
  url1  = "https://huggingface.co/atsuwo/atwmix_test2/resolve/main/atwmix_test2.ckpt" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/atwmix_test2.ckpt"

elif model_name == "Graham_Special":
  url1  = "https://huggingface.co/Graham-san/Graham_Special/resolve/main/Graham%20Special%20v1.ckpt" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Graham_Special.ckpt"

elif model_name == "ACertainModel":
  url1  = "https://huggingface.co/JosephusCheung/ACertainModel/resolve/main/ACertainModel.ckpt" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/ACertainModel.ckpt"

elif model_name == "BalorV2featAbyssOrange2":
  url1  = "https://huggingface.co/ploughB660/Balor-V2/resolve/main/BalorV2featAbyssOrange2.safetensors" 
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/BalorV2featAbyssOrange2.safetensors"

elif model_name == "Balor-V2.5featAOM3A3":
  url1  = "https://huggingface.co/ploughB660/Balor-V3/resolve/main/Balor-V2.5featAOM3A3.safetensors"
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/Balor-V2.5featAOM3A3.safetensors"

elif model_name == "ChilloutMix":
  url1  = "https://civitai.com/api/download/models/11745"
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/ChilloutMix.safetensors"


elif model_name == "wd-1-5-beta2":
  url1  = "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-aesthetic-fp16.safetensors"
  path1 = "/content/stable-diffusion-webui/models/Stable-diffusion/wd-1-5-beta2-aesthetic-fp16.safetensors"


else:
  print("Invalid model name.")

# !wget $url1 -O $path1

# %%
#@title 3.VAE
#@markdown VAEを選択してから実行してください。

vae_name ="Anything-V3.0.vae.pt" #@param ["vae-ft-mse-840000-ema-pruned","vae-ft-mse-560000-ema-pruned","kl-f8-anime","kl-f8-anime2","Anything-V3.0.vae.pt","autoencoder_fix_kl-f8-trinart_characters","orangemix.vae.pt"] {allow-input: false}

if vae_name == "vae-ft-mse-840000-ema-pruned":
  url2  = "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors" 
  path2 = "/content/stable-diffusion-webui/models/Stable-diffusion/vae-ft-mse-840000-ema-pruned.vae.pt"

elif vae_name == "vae-ft-mse-560000-ema-pruned":
  url2  = "https://huggingface.co/stabilityai/sd-vae-ft-ema-original/resolve/main/vae-ft-ema-560000-ema-pruned.ckpt" 
  path2 = "/content/stable-diffusion-webui/models/Stable-diffusion/vae-ft-ema-560000-ema-pruned.vae.pt"

elif vae_name == "kl-f8-anime":
  url2  = "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime.ckpt" 
  path2 = "/content/stable-diffusion-webui/models/Stable-diffusion/kl-f8-anime.vae.pt"

elif vae_name == "kl-f8-anime2":
  url2  = "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt" 
  path2 = "/content/stable-diffusion-webui/models/Stable-diffusion/kl-f8-anime2.vae.pt"

elif vae_name == "Anything-V3.0.vae.pt":
  url2  = "https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt" 
  path2 = "/content/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.vae.pt"

elif vae_name == "autoencoder_fix_kl-f8-trinart_characters":
  url2  = "https://huggingface.co/naclbit/trinart_characters_19.2m_stable_diffusion_v1/resolve/main/autoencoder_fix_kl-f8-trinart_characters.ckpt" 
  path2 = "/content/stable-diffusion-webui/models/Stable-diffusion/autoencoder_fix_kl-f8-trinart_characters.vae.pt"

elif vae_name == "orangemix.vae.pt":
  url2  = "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt" 
  path2 = "/content/stable-diffusion-webui/models/Stable-diffusion/orangemix.vae.pt"

# !wget $url2 -O $path2

# %%
#@title カスタムモデル(任意)
model_type ="Checkpoint" #@param ["Checkpoint","Texual_Inversion","LoRA","LyCORIS"] {allow-input: false}
if model_type =="Checkpoint":
    pretrained_model == "/content/stable-diffusion-webui/models/Stable-diffusion"
elif model_type ="Texual_Inversion":
    pretrained_model == "/content/stable-diffusion-webui/embeddings"
elif model_type ="LoRA":
    pretrained_model == "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora"
elif model_type ="LyCORIS":
    pretrained_model == "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora"
  
modelUrl = ""  # @param {'type': 'string'}
def install(url):
    base_name = os.path.basename(url)

    if url.startswith("https://drive.google.com"):
        os.chdir(pretrained_model)
        # !gdown --fuzzy {url}
    elif url.startswith("https://huggingface.co/"):
        if "/blob/" in url:
            url = url.replace("/blob/", "/resolve/")
        hf_token = ""  # @param {type:"string"}
        user_header = f'"Authorization: Bearer {hf_token}"'
        # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {pretrained_model} -o {base_name} {url}
    else:
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d {pretrained_model} {url}

# %%
#@title  LoRA･Textual Inversion･Lycoris（任意）
Lora_name ="None" #@param ["None","Anime_Screencap_Style_LoRA","One_Piece_Wano_Style_LoRA","Eula_LoRA","Yelan_LoRA","Barbara_LoRA","Diluc_LoRA","Mona_LoRA","Ganyu_LoRA","Jean_LoRA","Kujou_Sara_LoRA","Lisa_LoRA","Raiden_Shogun_LoRA","Shenhe_LoRA","Yoimiya_LoRA","Zhongli_LoRA","Yae_Miko_LoRA"] {allow-input:false}

if Lora_name == "None":
  url3  = None 
  path3 = None

elif Lora_name == "Anime_Screencap_Style_LoRA":
  url3  = "https://civitai.com/api/download/models/5742" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Anime_Screencap_Style_LoRA.safetensors"

elif Lora_name == "One_Piece_Wano_Style_LoRA":
  url3  = "https://civitai.com/api/download/models/6331" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/One_Piece_Wano_Style_LoRA.safetensors"

elif Lora_name == "Eula_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Eula/eulaMedium.safetensors" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Eula_LoRA.safetensors"

elif Lora_name == "Yelan_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Yelan/Yelan_Hard.safetensors" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Yelan_LoRA.safetensors"

elif Lora_name == "Barbara_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Barbara/Barbara_mediumpruned.safetensors" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Barbara_LoRA.safetensors"

elif Lora_name == "Diluc_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Diluc/Diluc_Mediumpruned.safetensors" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Diluc_LoRA.safetensors"

elif Lora_name == "Mona_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Mona/Mona_mediumpruned.safetensors" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Mona_LoRA.safetensors"

elif Lora_name == "Ganyu_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Ganyu/Ganyu_Medium.safetensors" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Ganyu_LoRA.safetensors"

elif Lora_name == "Jean_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Jean/Jean_Medium.safetensors" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Jean_LoRA.safetensors"

elif Lora_name == "Kujou_Sara_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Kujou%20Sara/kujou%20sara_Heavy.safetensors" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/kujou_sara_LoRA.safetensors"

elif Lora_name == "Lisa_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Lisa/Lisa_Medium.safetensors" 
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Lisa_LoRA.safetensors"

elif Lora_name == "Raiden_Shogun_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Raiden%20Shogun/raiden%20shogun_LoRA.safetensors"
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Raiden_Shogun_LoRA.safetensors"

elif Lora_name == "Shenhe_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Shenhe/Shenhe_Medium.safetensors"
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Shenhe_LoRA.safetensors"

elif Lora_name == "Yoimiya_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Yoimiya/Yoimiya_mediumpruned.safetensors"
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Yoimiya_LoRA.safetensors"

elif Lora_name == "Zhongli_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Zhongli/Zhongli_Medium.safetensors"
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Zhongli_LoRA.safetensors"

elif Lora_name == "Yae_Miko_LoRA":
  url3  = "https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/yae%20miko/yae%20miko_Mediumpruned.safetensors"
  path3 = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Yae_Miko_LoRA.safetensors"

else:
  print("Invalid Lora name.")

# !wget $url3 -O $path3

#Textual Inversion
Textual_name ="None"#@param ["None","Corneo's Makima","Corneo_Power","Yor Forger","Corneo's POV Bound Wrists Missionary","Corneo's Spitroast Threesome","Corneo's Anal sex","Corneo's Side-view Deepthroat","Corneo's Covering Breasts -Two Hands","Corneo's X-shaped Nipple Pasties","Corneo's POV Oral","Corneo's POV Paizuri","Corneo's Covering Breasts -One Arm","Corneo's Arm Grab Doggystyle","Corneo's Covering Breasts -Arms Crossed","Licking Oral"] {allow-input:false}

if Textual_name == "None":
  url4  = None 
  path4 = None

if Textual_name == "Corneo's Makima":
  url4  = "https://civitai.com/api/download/models/6197"
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_Makima.pt"

elif Textual_name == "Corneo_Power":
  url4  = "https://civitai.com/api/download/models/6027" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_Power.pt"

elif Textual_name == "Yor Forger":
  url4  = "https://civitai.com/api/download/models/6300" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_POV.pt"

elif Textual_name == "Corneo's POV Bound Wrists Missionary":
  url4  = "https://civitai.com/api/download/models/5405" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_POV.pt"

elif Textual_name == "Corneo's Spitroast Threesome":
  url4  = "https://civitai.com/api/download/models/6770" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_Spitroast_Threesome.pt"

elif Textual_name == "Corneo's Anal sex":
  url4  = "https://civitai.com/api/download/models/4597" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_Anal.pt"

elif Textual_name == "Corneo's Side-view Deepthroat":
  url4  = "https://civitai.com/api/download/models/6242" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_Side-view_Deepthroat.pt"

elif Textual_name == "Corneo's Covering Breasts -Two Hands":
  url4  = "https://civitai.com/api/download/models/6033" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_Covering_Breasts.pt"

elif Textual_name == "Corneo's X-shaped Nipple Pasties":
  url4  = "https://civitai.com/api/download/models/6318" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_Nipple_Pasties.pt"

elif Textual_name == "Corneo's POV Oral":
  url4  = "https://civitai.com/api/download/models/5051" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_POV_Oral.pt"

elif Textual_name == "Corneo's POV Paizuri":
  url4  = "https://civitai.com/api/download/models/5066" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_POV_Paizuri.pt"

elif Textual_name == "Corneo's Covering Breasts -One Arm":
  url4  = "https://civitai.com/api/download/models/6034" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_Covering_Breasts-One.pt"

elif Textual_name == "Corneo's Arm Grab Doggystyle":
  url4  = "https://civitai.com/api/download/models/5160" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_Arm_Grab_Doggystyle.pt"

elif Textual_name == "Corneo's Covering Breasts -Arms Crossed":
  url4  = "https://civitai.com/api/download/models/5746" 
  path4 = "/content/stable-diffusion-webui/embeddings/Corneo_Covering_Breasts-Arms_Crossed.pt"

elif Textual_name == "Licking Oral":
  url4  = "https://civitai.com/api/download/models/5746" 
  path4 = "/content/stable-diffusion-webui/embeddings/Licking_Oral.pt"

else:
  print("Invalid model name.")

# !wget $url4 -O $path4

#Lycoris
Lycoris_name ="None"#@param ["None"] {allow-input:false}
#準備中

# %%
#@title  4.WebUIの起動
# !sed -i -e '''/prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/stable-diffusion-webui/launch.py
# !python launch.py --share --xformers --enable-insecure-extension-access --gradio-queue --no-half-vae

# %% [markdown]
# ▼学習済みモデルの検索<br>
# [HuggingFace](https://huggingface.co/ckpt)<br>
# [Civitai](https://civitai.com/)<br>
# <br>
# ▼Colabページの説明<br>
# [stable-diffusion-webui-colab-japanese](https://github.com/AI-Nios/stable-diffusion-webui-colab-japanese)<br>
# <br>
# ▼新バージョン<br>
# [Nios_v3.ipynb](https://colab.research.google.com/github/AI-Nios/Nios-stable-diffusion-webui-colab-japan/blob/main/Nios_v3.ipynb)<br>
# <br>
# ▼記事<br>
# [Google Colabで画像生成AIの色々なモデルを簡単に使おう](https://note.com/ai_nios/n/n0826a33edc8a)<br>
# <br>
# ▼ColabでLoRA学習<br>
# [Linaqruf/kohya-trainer](https://github.com/Linaqruf/kohya-trainer)
# <br>
# [あかちゃんLoRAノートブック](https://seesaawiki.jp/nai_ch/d/kohya_train_network_simple)<br>
# もしくはこちら<br>
# [【最新バージョン】Loraモデル学習をGoogle Colabで作る方法解説。Kohya LoRA Dreambooth v14.1使用。【Stable Diffusion】](https://www.youtube.com/watch?v=ddpaECgRCHg&ab_channel=ShinanoMatsumoto%E3%83%BB%E6%99%B4%E3%82%8C%E6%99%82%E3%80%85%E3%82%AC%E3%82%B8%E3%82%A7%E3%83%83%E3%83%88)<br>
# もしくはこちら<br>
# [【StableDiffusion】初めてのAIお絵かき講座 その4 キャラや絵柄を追加学習！LoRA編【Anything V4.5】](https://www.nicovideo.jp/watch/sm41895651)
