# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-Nios/stable-diffusion-webui-colab-japanese/blob/main/Nios_v2_update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 1.WebUIのインストール
#パッケージインストール
# !pip install -q https://github.com/camenduru/stable-diffusion-webui-colab/releases/download/0.0.17/xformers-0.0.17+b6be33a.d20230315-cp39-cp39-linux_x86_64.whl
# !pip install -q --pre triton
#WebUIのインストール
# !git clone -b v2.0 https://github.com/camenduru/stable-diffusion-webui
#Extensions1 絶対入れておくべき
# !git clone https://github.com/alemelis/sd-webui-ar.git /content/stable-diffusion-webui/extensions/sd-webui-ar
# !git clone https://github.com/yfszzx/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git /content/stable-diffusion-webui/extensions/a1111-sd-webui-tagcomplete
# !git clone https://github.com/camenduru/stable-diffusion-webui-huggingface /content/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface
#Extensions2　任意
Extensions = True #@param {'type':'boolean'}
if Extensions == True :
  # !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui
  # !git clone https://github.com/toshiaki1729/stable-diffusion-webui-dataset-tag-editor.git /content/stable-diffusion-webui/extensions/dataset-tag-editor
  # !git clone https://github.com/bbc-mc/sdweb-merge-block-weighted-gui /content/stable-diffusion-webui/extensions/sdweb-merge-block-weighted-gui
  # !git clone -b v2.0 https://github.com/camenduru/sd-civitai-browser /content/stable-diffusion-webui/extensions/sd-civitai-browser
  # !git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/stable-diffusion-webui/extensions/sd-webui-additional-networks
  # !git clone https://github.com/opparco/stable-diffusion-webui-two-shot.git /content/stable-diffusion-webui/extensions/stable-diffusion-webui-two-shot
  # !git apply --ignore-whitespace /extensions/stable-diffusion-webui-two-shot/cfg_denoised_callback-ea9bd9fc.patch
  # !git clone https://github.com/hallatore/stable-diffusion-webui-chatgpt-utilities /content/stable-diffusion-webui/extensions/stable-diffusion-webui-chatgpt-utilities
  # !git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-locon.git /content/stable-diffusion-webui/extensions/a1111-sd-webui-locon
  # !git clone https://github.com/hnmr293/sd-webui-llul /content/stable-diffusion-webui/extensions/sd-webui-llul
  # !git clone https://github.com/butaixianran/Stable-Diffusion-Webui-Civitai-Helper.git /content/stable-diffusion-webui/extensions/Stable-Diffusion-Webui-Civitai-Helper
  # !git clone https://github.com/hnmr293/sd-webui-cutoff /content/stable-diffusion-webui/extensions/sd-webui-cutoff
  # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-wildcards.git /content/stable-diffusion-webui/extensions/stable-diffusion-webui-wildcards
# %cd /content/stable-diffusion-webui
#Extensions3(ControlNet)　任意
ControlNet = True #@param {'type':'boolean'}
if ControlNet == True :
  # !git clone https://github.com/camenduru/openpose-editor /content/stable-diffusion-webui/extensions/openpose-editor
  # !git clone https://github.com/Mikubill/sd-webui-controlnet.git /content/stable-diffusion-webui/extensions/sd-webui-controlnet
  # !git clone https://github.com/jexom/sd-webui-depth-lib /content/stable-diffusion-webui/extensions/sd-webui-depth-lib
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_canny-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_depth-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_hed-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_mlsd-fp16.safetensorss
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_normal-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_openpose-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_scribble-fp16.safetensors
  # !wget https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors -O /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_seg-fp16.safetensors

# %cd /content/stable-diffusion-webui

#EasyNegative
# !wget https://huggingface.co/datasets/gsdf/EasyNegative/resolve/main/EasyNegative.pt -O /content/stable-diffusion-webui/embeddings/EasyNegative.pt

#ドライブをマウント
mount_drive = False # @param {type: "boolean"}

if mount_drive:
    from google.colab import drive
    if not os.path.exists("/content/drive"):
        drive.mount("/content/drive")

# %%
#@title  2.モデル選択
#@markdown モデルを選択してから実行してください。

import os

model_name ="pastel_mix" #@param ["stable_diffusion_v1.5","stable_diffusion_v2.1","waifu_diffusion_v1.3","Openjourney","anything-v3.0","anything-v4.0","Counterfeit-V2.0","8528-diffusion","AbyssOrangeMix2","EerieOrangeMix2","trinart2_step115000","Eimis Anime Diffusion_1.0v","dreamlike-photoreal-2.0","Cyberpunk-Anime-Diffusion","Plat_Diffusion_v1.3.1","ACertainThing","pastel_mix","anything-v4.5","Basil_mix_fixed","Realistic_Vision_V1.3","Counterfeit-V2.5","SukiyakiMix-v1.0","7th_anime_v1.1","7th_anime_v2_C","7th_anime_v3_A","YuzuGinger_v4","YuzuLemonMilk_v1.5", "Defmix-v1.1","RDtMix","Corneo's 7th Heaven Mix","ChilloutMix","wd-1-5-beta2"] {allow-input: false}

model_dict={
    "stable_diffusion_v1.5":"https://huggingface.co/camenduru/sd15/resolve/main/v1-5-pruned-emaonly.ckpt",
    "stable_diffusion_v2.1":"https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.ckpt",
    "waifu_diffusion_v1.3":"https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt",
    "Openjourney":"https://huggingface.co/prompthero/openjourney/resolve/main/mdjrny-v4.safetensors",
    "anything-v3.0":"https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/anything-v3-fp32-pruned.safetensors",
    "anything-v4.0":"https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned.ckpt",
    "anything-v4.5":"https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned.safetensors",
    "Counterfeit-V2.0":"https://huggingface.co/gsdf/Counterfeit-V2.0/resolve/main/Counterfeit-V2.0fp16.safetensors",
    "Counterfeit-V2.5":"https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5_pruned.safetensors",
    "8528-diffusion":"https://huggingface.co/852wa/8528-diffusion/resolve/main/8528d-final.ckpt",
    "AbyssOrangeMix2":"https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_nsfw.safetensors",
    "EerieOrangeMix2":"https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/EerieOrangeMix/EerieOrangeMix2.safetensors",
    "trinart2_step115000":"https://huggingface.co/naclbit/trinart_stable_diffusion_v2/resolve/main/trinart2_step115000.ckpt",
    "EimisAnimeDiffusion_1.0v":"https://huggingface.co/eimiss/EimisAnimeDiffusion_1.0v/resolve/main/EimisAnimeDiffusion_1-0v.ckpt",
    "dreamlike-photoreal-2.0":"https://huggingface.co/dreamlike-art/dreamlike-photoreal-2.0/resolve/main/dreamlike-photoreal-2.0.safetensors",
    "Cyberpunk-Anime-Diffusion":"https://huggingface.co/DGSpitzer/Cyberpunk-Anime-Diffusion/resolve/main/Cyberpunk-Anime-Diffusion.ckpt",
    "Plat_Diffusion_v1.3.1":"https://huggingface.co/p1atdev/pd-archive/resolve/main/plat-v1-3-1.safetensors",
    "ACertainThing":"https://huggingface.co/JosephusCheung/ACertainThing/resolve/main/ACertainThing.ckpt",
    "pastel_mix":"https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-better-vae-fp16.safetensors",
    "Basil_mix_fixed":"https://huggingface.co/nuigurumi/basil_mix/resolve/main/Basil_mix_fixed.safetensors",
    "Realistic_Vision_V1.3":"https://civitai.com/api/download/models/6987",
    "SukiyakiMix-v1.0":"https://huggingface.co/Vsukiyaki/SukiyakiMix-v1.0/resolve/main/SukiyakiMix-v1.0-fp16.safetensors",
    "7th_anime_v1.1":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v1/7th_anime_v1.1.safetensors",
    "7th_anime_v2_A":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_A.safetensors",
    "7th_anime_v2_B":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_B.safetensors",
    "7th_anime_v2_C":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_C.safetensors",
    "7th_anime_v2_G":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_G.safetensors",
    "7th_anime_v3_A":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_A.safetensors",
    "7th_anime_v3_B":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_B.safetensors",
    "7th_anime_v3_C":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_C.safetensors",
    "7th_anime_3.1_B":"https://huggingface.co/syaimu/7th_test/resolve/main/7th_anime_3.1_B.ckpt",
    "YuzuGinger_v4":"https://huggingface.co/thiros/YuzuLemonTea/resolve/main/YuzuGinger_v4-pruned.safetensors",
    "YuzuLemonMilk_v1.5":"https://huggingface.co/thiros/YuzuLemonTea/resolve/main/YuzuLemonMilk_v1.5-pruned.safetensors",
    "Defmix-v1.1":"https://huggingface.co/Defpoint/Defmix-v1.0/resolve/main/Defmix-v1.1.safetensors",
    "RDtMix":"https://huggingface.co/Hemlok/DateMix/resolve/main/RDtMix-fp16.safetensors",
    "meadmix":"https://huggingface.co/sazanka-imoto/MeadMix/resolve/main/meadmix.safetensors",
    "Nabylon-v1.0":"https://huggingface.co/NegiInNattoMaki/Nabylon-v1.0/resolve/main/Nabylon-v1.0-fp16.safetensors",
    "LonganMix":"https://huggingface.co/Hemlok/LonganMix/resolve/main/LonganMix-fp16.ckpt",
    "Corneo's7thHeavenMix":"https://civitai.com/api/download/models/5338",
    "Corneo'sShinra26Mix":"https://civitai.com/api/download/models/6918",
    "atwmix_test2":"https://huggingface.co/atsuwo/atwmix_test2/resolve/main/atwmix_test2.ckpt",
    "Graham_Special":"https://huggingface.co/Graham-san/Graham_Special/resolve/main/Graham%20Special%20v1.ckpt",
    "BalorV2featAbyssOrange2":"https://huggingface.co/ploughB660/Balor-V2/resolve/main/BalorV2featAbyssOrange2.safetensors",
    "Balor-V2.5featAOM3A3":"https://huggingface.co/ploughB660/Balor-V3/resolve/main/Balor-V2.5featAOM3A3.safetensors",
    "ChilloutMix":"https://civitai.com/api/download/models/11745",
    "wd-1-5-beta2":"https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-aesthetic-fp16.safetensors",
}


model_url = model_dict.get(model_name)

def install(model_url):
    base_name = os.path.basename(model_url)

    if model_url.startswith("https://drive.google.com"):
        os.chdir(pretrained_model)
        # !gdown --fuzzy {model_url}
    elif model_url.startswith("https://huggingface.co/"):
        if "/blob/" in model_url:
            model_url = model_url.replace("/blob/", "/resolve/")
        huggingface_token ="YOUR_HUGGINGFACE_TOKEN" # 自分のトークンに変更
        user_header = f'"Authorization: Bearer {huggingface_token}"'
        # !wget --no-check-certificate --header={user_header} $model_url -O /content/stable-diffusion-webui/models/Stable-diffusion/$base_name
    else:
        # !wget $model_url -O /content/stable-diffusion-webui/models/Stable-diffusion/{model_name}.safetensors
 
install(model_url)

# %%
#@title 3.VAE
#@markdown VAEを選択してから実行してください。

vae_name = "orangemix" #@param ["vae-ft-mse-840000-ema-pruned","vae-ft-mse-560000-ema-pruned","kl-f8-anime","kl-f8-anime2","Anything-V3.0","autoencoder_fix_kl-f8-trinart_characters","orangemix"] {allow-input: false}

url_dict = {
    "vae-ft-mse-840000-ema-pruned": "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors",
    "vae-ft-mse-560000-ema-pruned": "https://huggingface.co/stabilityai/sd-vae-ft-ema-original/resolve/main/vae-ft-ema-560000-ema-pruned.ckpt",
    "kl-f8-anime": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime.ckpt",
    "kl-f8-anime2": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt",
    "Anything-V3.0": "https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt",
    "autoencoder_fix_kl-f8-trinart_characters": "https://huggingface.co/naclbit/trinart_characters_19.2m_stable_diffusion_v1/resolve/main/autoencoder_fix_kl-f8-trinart_characters.ckpt",
    "orangemix": "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt",
}

vae_url = url_dict.get(vae_name)

def install(vae_url):
    base_name = os.path.basename(vae_url)
    if vae_url.startswith("https://drive.google.com"):
        os.chdir(pretrained_model)
        # !gdown --fuzzy {vae_url}
    elif vae_url.startswith("https://huggingface.co/"):
        if "/blob/" in vae_url:
            vae_url = vae_url.replace("/blob/", "/resolve/")
        huggingface_token = "" 
        user_header = f'"Authorization: Bearer {huggingface_token}"'
        # !wget $vae_url -O /content/stable-diffusion-webui/models/Stable-diffusion/{vae_name}.vae.pt
    else: 
        # !wget $vae_url -O /content/stable-diffusion-webui/models/Stable-diffusion/{vae_name}.vae.pt

install(vae_url)

# %%
#@title カスタムモデル(任意)
 #@markdown [実行方法](https://twitter.com/ai_nios/status/1639659834240008192?s=20)
model_type ="LoRA" #@param ["Checkpoint","Hypernetwork","Texual_Inversion","Aesthetic_Gradients","LoRA","LyCORIS","Wildcards","VAE"] {allow-input: false}
if model_type == "Checkpoint":
    pretrained_model = "/content/stable-diffusion-webui/models/Stable-diffusion"
elif model_type =="Texual_Inversion":
    pretrained_model = "/content/stable-diffusion-webui/embeddings"
elif model_type == "Hypernetwork":
    # !git https://github.com/antis0007/sd-webui-multiple-hypernetworks.git /content/stable-diffusion-webui/extensions/sd-webui-multiple-hypernetworks
    pretrained_model = "/content/stable-diffusion-webui/extensions/sd-webui-multiple-hypernetworks"
elif model_type =="Aesthetic_Gradients":
    pretrained_model = "/content/stable-diffusion-webui/embeddings"
elif model_type == "LoRA":
    pretrained_model = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora"
elif model_type == "LyCORIS":
    pretrained_model = "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora"
elif model_type == "Wildcards":
    # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-wildcards.git /content/stable-diffusion-webui/extensions/stable-diffusion-webui-wildcards
    pretrained_model = "/content/stable-diffusion-webui/extensions/stable-diffusion-webui-wildcards/wildcards"
elif model_type == "VAE":
    pretrained_model = "/content/stable-diffusion-webui/models/Stable-diffusion"

modelUrl = ""  # @param {'type': 'string'}
 
if modelUrl == "":
  print("")
else:
  def install(url):
      base_name = os.path.basename(url)

      if url.startswith("https://drive.google.com"):
          os.chdir(pretrained_model)
          # !gdown --fuzzy {url}
      elif url.startswith("https://huggingface.co/"):
          if "/blob/" in url:
              url = url.replace("/blob/", "/resolve/")
                  #@markdown ▼Hugging Faceのプライベートモデルを使用する場合、[アクセストークン](https://huggingface.co/settings/tokens)を入力してください。
          huggingface_token = ""  # @param {type:"string"}
          user_header = f'"Authorization: Bearer {huggingface_token}"'
          # !wget --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16  {url} -o {pretrained_model}{base_name}
      else:
          # !wget {url} -o {pretrained_model}/{base_name}

  install(modelUrl)

#@markdown ▼driveからファイルをコピーする場合、[ファイルパス](https://camo.qiitausercontent.)を入力してください。ファイルが見つからない場合はスキップされます。
drivePath = "\u4F8B:/content/drive/MyDrive/LoRA/iroha.safetensors" #@param {type: "string"}

if drivePath:
  if "例:" in drivePath:
    print("")
  else:
    from google.colab import drive
    if not os.path.exists("/content/drive"):
      drive.mount("/content/drive")
    # check if file exists in drivePath
    if not os.path.exists(drivePath):
      # check if file exists with "/" prefix
      if not os.path.exists("/" + drivePath):
        # check if file exists with "/content/drive/MyDrive/" prefix
        if not os.path.exists("/content/drive/MyDrive/" + drivePath):
          # check if file exists with "/content/drive/MyDrive/LoRA/" prefix
          if not os.path.exists("/content/drive/MyDrive/LoRA/" + drivePath):
            print(f"{drivePath} does not exist. Skipping copying step.")
          else:
            drivePath = "/content/drive/MyDrive/LoRA/" + drivePath
        else:
          drivePath = "/content/drive/MyDrive/" + drivePath
      else:
        drivePath = "/" + drivePath
    # !cp {drivePath} {pretrained_model}
    print("コピーしました。")
else:
  print("")

# %%
#@title 追加学習モデル LoRA・Textual Inversion･Lycoris（任意）


Lora_name ="" #@param ["","Anime_Screencap_Style_LoRA","One_Piece_Wano_Style_LoRA","Eula_LoRA","Yelan_LoRA","Barbara_LoRA","Diluc_LoRA","Mona_LoRA","Ganyu_LoRA","Jean_LoRA","Kujou_Sara_LoRA","Lisa_LoRA","Raiden_Shogun_LoRA","Shenhe_LoRA","Yoimiya_LoRA","Zhongli_LoRA","Yae_Miko_LoRA"] {allow-input:false}

Lora_dict={
	"Anime_Screencap_Style_LoRA":"https://civitai.com/api/download/models/5742" ,
	"One_Piece_Wano_Style_LoRA":"https://civitai.com/api/download/models/6331" ,
	"Eula_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Eula/eulaMedium.safetensors" ,
	"Yelan_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Yelan/Yelan_Hard.safetensors" ,
	"Barbara_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Barbara/Barbara_mediumpruned.safetensors", 
	"Diluc_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Diluc/Diluc_Mediumpruned.safetensors" ,
	"Mona_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Mona/Mona_mediumpruned.safetensors" ,
	"Ganyu_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Ganyu/Ganyu_Medium.safetensors" ,
	"Jean_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Jean/Jean_Medium.safetensors" ,
	"Kujou_Sara_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Kujou%20Sara/kujou%20sara_Heavy.safetensors",
	"Lisa_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Lisa/Lisa_Medium.safetensors",
	"Raiden_Shogun_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Raiden%20Shogun/raiden%20shogun_LoRA.safetensors",
	"Shenhe_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Shenhe/Shenhe_Medium.safetensors",
	"Yoimiya_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Yoimiya/Yoimiya_mediumpruned.safetensors",
	"Zhongli_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/Zhongli/Zhongli_Medium.safetensors",
	"Yae_Miko_LoRA":"https://huggingface.co/YoungMasterFromSect/Trauter_LoRAs/resolve/main/LoRA/Genshin-Impact/yae%20miko/yae%20miko_Mediumpruned.safetensors",
}

Textual_name =""#@param ["","Corneo's Makima","Corneo_Power","Yor Forger","Corneo's POV Bound Wrists Missionary","Corneo's Spitroast Threesome","Corneo's Anal sex","Corneo's Side-view Deepthroat","Corneo's Covering Breasts -Two Hands","Corneo's X-shaped Nipple Pasties","Corneo's POV Oral","Corneo's POV Paizuri","Corneo's Covering Breasts -One Arm","Corneo's Arm Grab Doggystyle","Corneo's Covering Breasts -Arms Crossed","Licking Oral"] {allow-input:false}

Textual_dict={
	"Corneo's Makima":"https://civitai.com/api/download/models/6197",
	"Corneo_Power":"https://civitai.com/api/download/models/6027" ,
	"Yor Forger":"https://civitai.com/api/download/models/6300" ,
	"Corneo's POV Bound Wrists Missionary":"https://civitai.com/api/download/models/5405", 
	"Corneo's Spitroast Threesome":"https://civitai.com/api/download/models/6770",
	"Corneo's Anal sex":"https://civitai.com/api/download/models/4597" ,
	"Corneo's Side-view Deepthroat":"https://civitai.com/api/download/models/6242" ,
	"Corneo's Covering Breasts -Two Hands":"https://civitai.com/api/download/models/6033" ,
	"Corneo's X-shaped Nipple Pasties":"https://civitai.com/api/download/models/6318" ,
	"Corneo's POV Oral":"https://civitai.com/api/download/models/5051" ,
	"Corneo's POV Paizuri":"https://civitai.com/api/download/models/5066", 
	"Corneo's Covering Breasts -One Arm":"https://civitai.com/api/download/models/6034", 
	"Corneo's Arm Grab Doggystyle":"https://civitai.com/api/download/models/5160" ,
	"Corneo's Covering Breasts -Arms Crossed":"https://civitai.com/api/download/models/5746", 
	"Licking Oral":"https://civitai.com/api/download/models/5746" ,
}

#Lycoris-LoRA
Lycoris_name ="" #@param [""] {allow-input:false}
#準備中
Lycoris_dict={"":""}

Lora_url = Lora_dict.get(Lora_name)
Textual_url = Textual_dict.get(Textual_name)
Lycoris_url = Lycoris_dict.get(Lycoris_name)

def install(Lora_url, Textual_url, Lycoris_url):
    if Lora_url:
        base_name = os.path.basename(Lora_url)
        # !wget {Lora_url} -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/{base_name} 
     
    if Textual_url :
        base_name = os.path.basename(Textual_url)
        # !wget {Textual_url} -O /content/stable-diffusion-webui/embeddings/{base_name} 

    if Lycoris_url :
        base_name = os.path.basename(Lycoris_url)
        # !wget {Lycoris_url} -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/{base_name} 
						
install(Lora_url, Textual_url,Lycoris_url)

# %%
#@title  4.WebUIの起動
# !sed -i -e '''/prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/stable-diffusion-webui/launch.py
# !python launch.py --share --xformers --enable-insecure-extension-access --gradio-queue --no-half-vae

# %% [markdown]
# ▼学習済みモデルの検索<br>
# [HuggingFace](https://huggingface.co/ckpt)<br>
# [Civitai](https://civitai.com/)<br>
# <br>
# ▼Colabページの説明<br>
# [stable-diffusion-webui-colab-japanese](https://github.com/AI-Nios/stable-diffusion-webui-colab-japanese)<br>
# <br>
# ▼新バージョン<br>
# [Nios_v3.ipynb](https://colab.research.google.com/github/AI-Nios/Nios-stable-diffusion-webui-colab-japan/blob/main/Nios_v3.ipynb)<br>
# <br>
# ▼記事<br>
# [Google Colabで画像生成AIの色々なモデルを簡単に使おう](https://note.com/ai_nios/n/n0826a33edc8a)<br>
# <br>
# ▼ColabでLoRA学習<br>
# [Linaqruf/kohya-trainer](https://github.com/Linaqruf/kohya-trainer)
# <br>
# [あかちゃんLoRAノートブック](https://seesaawiki.jp/nai_ch/d/kohya_train_network_simple)<br>
# もしくはこちら<br>
# [【最新バージョン】Loraモデル学習をGoogle Colabで作る方法解説。Kohya LoRA Dreambooth v14.1使用。【Stable Diffusion】](https://www.youtube.com/watch?v=ddpaECgRCHg&ab_channel=ShinanoMatsumoto%E3%83%BB%E6%99%B4%E3%82%8C%E6%99%82%E3%80%85%E3%82%AC%E3%82%B8%E3%82%A7%E3%83%83%E3%83%88)<br>
# もしくはこちら<br>
# [【StableDiffusion】初めてのAIお絵かき講座 その4 キャラや絵柄を追加学習！LoRA編【Anything V4.5】](https://www.nicovideo.jp/watch/sm41895651)
