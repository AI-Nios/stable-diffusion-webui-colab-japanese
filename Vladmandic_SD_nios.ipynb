# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-Nios/stable-diffusion-webui-colab-japanese/blob/main/Vladmandic_SD_nios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Vladmandic SD

#ドライブをマウント
Mount_Drive = False # @param {type: "boolean"}

if Mount_Drive:
    import os
    from google.colab import drive
    if not os.path.exists("/content/drive"):
        drive.mount("/content/drive")
        
# !apt -y install -qq aria2
# !pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
# !pip install -q xformers==0.0.18 triton==2.0.0 -U
# %cd /content

# !git clone https://github.com/vladmandic/automatic

# %%
#@title  2.モデル選択

import os

model_name ="7th_anime_v3_A" #@param ["stable_diffusion_v1.5","stable_diffusion_v2.1","waifu_diffusion_v1.3","Openjourney","anything-v3.0","anything-v4.0","anything-v4.5","Counterfeit-V2.0","Counterfeit-V2.5","8528-diffusion","AbyssOrangeMix2","EerieOrangeMix2","trinart2_step115000","Eimis_Anime_Diffusion_1.0v","dreamlike-photoreal-2.0","Cyberpunk-Anime-Diffusion","Plat_Diffusion_v1.3.1","ACertainThing","pastel_mix","Basil_mix_fixed","Realistic_Vision_V1.3","SukiyakiMix-v1.0","7th_anime_v1.1", "7th_anime_v2_A", "7th_anime_v2_B", "7th_anime_v2_C", "7th_anime_v2_G","7th_anime_v3_A", "7th_anime_v3_B", "7th_anime_v3_C","7th_anime_3.1_B","YuzuGinger_v4","YuzuLemonMilk_v1.5", "Defmix-v1.1","RDtMix","meadmix","Nabylon-v1.0","LonganMix","Corneo's_7th_Heaven_Mix", "Corneo's_Shinra26_Mix","atwmix_test2","Graham_Special", "BalorV2featAbyssOrange2","Balor-V2.5featAOM3A3","ChilloutMix", "wd-1-5-beta2","AniReality-Mix"] {allow-input: false}

model_dict={
    "stable_diffusion_v1.5":"https://huggingface.co/camenduru/sd15/resolve/main/v1-5-pruned-emaonly.ckpt",
    "stable_diffusion_v2.1":"https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.ckpt",
    "waifu_diffusion_v1.3":"https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt",
    "Openjourney":"https://huggingface.co/prompthero/openjourney/resolve/main/mdjrny-v4.safetensors",
    "anything-v3.0":"https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/anything-v3-fp32-pruned.safetensors",
    "anything-v4.0":"https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned.ckpt",
    "anything-v4.5":"https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned.safetensors",
    "Counterfeit-V2.0":"https://huggingface.co/gsdf/Counterfeit-V2.0/resolve/main/Counterfeit-V2.0fp16.safetensors",
    "Counterfeit-V2.5":"https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5_pruned.safetensors",
    "8528-diffusion":"https://huggingface.co/852wa/8528-diffusion/resolve/main/8528d-final.ckpt",
    "AbyssOrangeMix2":"https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_nsfw.safetensors",
    "EerieOrangeMix2":"https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/EerieOrangeMix/EerieOrangeMix2.safetensors",
    "trinart2_step115000":"https://huggingface.co/naclbit/trinart_stable_diffusion_v2/resolve/main/trinart2_step115000.ckpt",
    "EimisAnimeDiffusion_1.0v":"https://huggingface.co/eimiss/EimisAnimeDiffusion_1.0v/resolve/main/EimisAnimeDiffusion_1-0v.ckpt",
    "dreamlike-photoreal-2.0":"https://huggingface.co/dreamlike-art/dreamlike-photoreal-2.0/resolve/main/dreamlike-photoreal-2.0.safetensors",
    "Cyberpunk-Anime-Diffusion":"https://huggingface.co/DGSpitzer/Cyberpunk-Anime-Diffusion/resolve/main/Cyberpunk-Anime-Diffusion.ckpt",
    "Plat_Diffusion_v1.3.1":"https://huggingface.co/p1atdev/pd-archive/resolve/main/plat-v1-3-1.safetensors",
    "ACertainThing":"https://huggingface.co/JosephusCheung/ACertainThing/resolve/main/ACertainThing.ckpt",
    "pastel_mix":"https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-better-vae-fp16.safetensors",
    "Basil_mix_fixed":"https://huggingface.co/nuigurumi/basil_mix/resolve/main/Basil_mix_fixed.safetensors",
    "Realistic_Vision_V1.3":"https://civitai.com/api/download/models/6987",
    "SukiyakiMix-v1.0":"https://huggingface.co/Vsukiyaki/SukiyakiMix-v1.0/resolve/main/SukiyakiMix-v1.0-fp16.safetensors",
    "7th_anime_v1.1":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v1/7th_anime_v1.1.safetensors",
    "7th_anime_v2_A":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_A.safetensors",
    "7th_anime_v2_B":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_B.safetensors",
    "7th_anime_v2_C":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_C.safetensors",
    "7th_anime_v2_G":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_G.safetensors",
    "7th_anime_v3_A":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_A.safetensors",
    "7th_anime_v3_B":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_B.safetensors",
    "7th_anime_v3_C":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_C.safetensors",
    "7th_anime_3.1_B":"https://huggingface.co/syaimu/7th_test/resolve/main/7th_anime_3.1_B.ckpt",
    "YuzuGinger_v4":"https://huggingface.co/thiros/YuzuLemonTea/resolve/main/YuzuGinger_v4-pruned.safetensors",
    "YuzuLemonMilk_v1.5":"https://huggingface.co/thiros/YuzuLemonTea/resolve/main/YuzuLemonMilk_v1.5-pruned.safetensors",
    "Defmix-v1.1":"https://huggingface.co/Defpoint/Defmix-v1.0/resolve/main/Defmix-v1.1.safetensors",
    "RDtMix":"https://huggingface.co/Hemlok/DateMix/resolve/main/RDtMix-fp16.safetensors",
    "meadmix":"https://huggingface.co/sazanka-imoto/MeadMix/resolve/main/meadmix.safetensors",
    "Nabylon-v1.0":"https://huggingface.co/NegiInNattoMaki/Nabylon-v1.0/resolve/main/Nabylon-v1.0-fp16.safetensors",
    "LonganMix":"https://huggingface.co/Hemlok/LonganMix/resolve/main/LonganMix-fp16.ckpt",
    "Corneo's_7th_Heaven_Mix":"https://civitai.com/api/download/models/5338",
    "Corneo's_Shinra26_Mix":"https://civitai.com/api/download/models/6918",
    "atwmix_test2":"https://huggingface.co/atsuwo/atwmix_test2/resolve/main/atwmix_test2.ckpt",
    "Graham_Special":"https://huggingface.co/Graham-san/Graham_Special/resolve/main/Graham%20Special%20v1.ckpt",
    "BalorV2featAbyssOrange2":"https://huggingface.co/ploughB660/Balor-V2/resolve/main/BalorV2featAbyssOrange2.safetensors",
    "Balor-V2.5featAOM3A3":"https://huggingface.co/ploughB660/Balor-V3/resolve/main/Balor-V2.5featAOM3A3.safetensors",
    "ChilloutMix":"https://civitai.com/api/download/models/11745",
    "wd-1-5-beta2":"https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-aesthetic-fp16.safetensors",
    "AniReality-Mix":"https://civitai.com/api/download/models/33305"
}
# !mkdir -p /content/models
# !apt -y install -qq aria2
model_url = model_dict.get(model_name)

def install(model_url):
    base_name = os.path.basename(model_url)

    if model_url.startswith("https://drive.google.com"):
        os.chdir("/content/models")
        # !gdown --fuzzy {model_url}
    elif model_url.startswith("https://huggingface.co/"):
        if "/blob/" in model_url:
            model_url = model_url.replace("/blob/", "/resolve/")
        huggingface_token ="YOUR_HUGGINGFACE_TOKEN" # 自分のトークンに変更
        user_header = f'"Authorization: Bearer {huggingface_token}"'
        # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M {model_url} -d /content/models -o {base_name} 
    else:
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d /content/models {model_url}
        
install(model_url)

# %%
#@title 3.VAE
import os

vae_name = "orangemix.vae.pt" #@param ["vae-ft-mse-840000-ema-pruned","vae-ft-mse-560000-ema-pruned","kl-f8-anime","kl-f8-anime2","Anything-V3.0.vae.pt","anything-v4.0.vae.pt","autoencoder_fix_kl-f8-trinart_characters","orangemix.vae.pt"] {allow-input: false}

url_dict = {
    "vae-ft-mse-840000-ema-pruned": "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors",
    "vae-ft-mse-560000-ema-pruned": "https://huggingface.co/stabilityai/sd-vae-ft-ema-original/resolve/main/vae-ft-ema-560000-ema-pruned.ckpt",
    "kl-f8-anime": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime.ckpt",
    "kl-f8-anime2": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt",
    "Anything-V3.0.vae.pt": "https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt",
    "anything-v4.0.vae.pt":"https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0.vae.pt",
    "autoencoder_fix_kl-f8-trinart_characters": "https://huggingface.co/naclbit/trinart_characters_19.2m_stable_diffusion_v1/resolve/main/autoencoder_fix_kl-f8-trinart_characters.ckpt",
    "orangemix.vae.pt": "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt",
}

vae_url = url_dict.get(vae_name)

def install(vae_url):
    base_name = os.path.basename(vae_url)
    if ".ckpt" in base_name or ".safetensors" in base_name:
        base_name = base_name.replace(".ckpt", ".vae.pt").replace(".safetensors", ".vae.pt") 
    # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 {vae_url} -d /content/models -o {base_name}           

    print(base_name)
     
install(vae_url)

# %%
# %cd /content/automatic
# !python launch.py --no-hashing --share --noupdate --skip-extensions --ckpt /content/models/7th_anime_v3_A.safetensors
# Out:
# /content/automatic
# 02:27:22-829620 INFO     Python 3.9.16 on Linux
# 02:27:22-875772 INFO     Version: def7a02d Wed Apr 26 16:08:56 2023 -0400
# 02:27:23-249574 INFO     Setting environment tuning
# 02:27:23-251282 INFO     nVidia toolkit detected
# 02:27:24-556356 INFO     Torch 2.0.0+cu118
# 02:27:24-579682 INFO     Torch backend: nVidia CUDA 11.8 cuDNN 8700
# 02:27:24-594096 INFO     Torch detected GPU: Tesla T4 VRAM 15102 Arch (7, 5)
#                          Cores 40
# 02:27:24-595844 INFO     Verifying requirements
# 02:27:24-616572 INFO     No changes detected: Quick launch active
# 02:27:24-618114 INFO     Running extension preloading
# 02:27:24-619120 INFO     Server arguments: ['--no-hashing', '--share',
#                          '--noupdate', '--skip-extensions', '--ckpt',
#                          '/content/models/7th_anime_v3_A.safetensors']
# Unloading xFormers
# Available models: /content/automatic/models/Stable-diffusion 1
# Module load:
# /content/automatic/extensions-builtin/clip-interrogator-ext/scripts/clip_interro
# gator_ext.py: ModuleNotFoundError
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/automatic/modules/script_loading.py:10 in load_module               │
# │                                                                              │
# │    9 │   try:                                                                │
# │ ❱ 10 │   │   module_spec.loader.exec_module(module)                          │
# │   11 │   except Exception as e:                                              │
# │ in exec_module:850                                                           │
# │ in _call_with_frames_removed:228                                             │
# │                                                                              │
# │ /content/automatic/extensions-builtin/clip-interrogator-ext/scripts/clip_int │
# │ errogator_ext.py:9 in <module>                                               │
# │                                                                              │
# │     8                                                                        │
# │ ❱   9 import clip_interrogator                                               │
# │    10 from clip_interrogator import Config, Interrogator                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'clip_interrogator'
# ControlNet v1.1.112
# ControlNet v1.1.112
# Module load:
# /content/automatic/extensions-builtin/stable-diffusion-webui-rembg/scripts/postp
# rocessing_rembg.py: ModuleNotFoundError
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/automatic/modules/script_loading.py:10 in load_module               │
# │                                                                              │
# │    9 │   try:                                                                │
# │ ❱ 10 │   │   module_spec.loader.exec_module(module)                          │
# │   11 │   except Exception as e:                                              │
# │ in exec_module:850                                                           │
# │ in _call_with_frames_removed:228                                             │
# │                                                                              │
# │ /content/automatic/extensions-builtin/stable-diffusion-webui-rembg/scripts/p │
# │ ostprocessing_rembg.py:5 in <module>                                         │
# │                                                                              │
# │    4 from modules.ui_components import FormRow                               │
# │ ❱  5 import rembg                                                            │
# │    6                                                                         │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'rembg'
# Loading theme: black-orange
# Image Browser: Creating database
# Image Browser: Database created
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://ffb0ff7a1493f6898b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# Initializing middleware
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
#                                                                    GB
# Creating model from config: /content/automatic/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Downloading (…)olve/main/vocab.json: 100% 961k/961k [00:01<00:00, 712kB/s]
# Downloading (…)olve/main/merges.txt: 100% 525k/525k [00:00<00:00, 39.0MB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 228kB/s]
# Downloading (…)okenizer_config.json: 100% 905/905 [00:00<00:00, 542kB/s]
# Downloading (…)lve/main/config.json: 100% 4.52k/4.52k [00:00<00:00, 744kB/s]
# Applying scaled dot product cross attention optimization
# Embeddings loaded:  (0)
# Model loaded in 23.3s (load=1.4s create=4.7s apply=15.1s vae=1.3s move=0.6s
# embeddings=0.1s)
# Startup time: 36.4s (torch=3.4s gradio=2.0s libraries=0.6s codeformer=0.2s
# scripts=1.5s ui=2.9s start=2.3s scripts app_started_callback=0.1s
# checkpoint=23.4s)
# Progress 1.61it/s ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:06
# Exiting

# %%
#@title Launch Vladmandic webui (GPU mode)
# %cd /content/automatic
# !COMMANDLINE_ARGS="--no-hashing --share --noupdate --skip-extensions --ckpt /content/models/7th_anime_v3_A.safetensors" REQS_FILE="requirements.txt" python launch.py
# Out:
# /content/automatic
# 02:33:13-248532 INFO     Python 3.9.16 on Linux
# 02:33:13-313136 INFO     Version: def7a02d Wed Apr 26 16:08:56 2023 -0400
# 02:33:13-438780 INFO     Setting environment tuning
# 02:33:13-441126 INFO     nVidia toolkit detected
# 02:33:15-840016 INFO     Torch 2.0.0+cu118
# 02:33:15-881649 INFO     Torch backend: nVidia CUDA 11.8 cuDNN 8700
# 02:33:15-898890 INFO     Torch detected GPU: Tesla T4 VRAM 15102 Arch (7, 5)
#                          Cores 40
# 02:33:15-901586 INFO     Verifying requirements
# 02:33:15-937881 INFO     Running setup
# 02:33:15-939746 INFO     Installing packages
# 02:33:15-941467 INFO     Installing repositories
# 02:33:16-008157 INFO     Installing submodules
# 02:33:16-584785 INFO     Extensions enabled: ['seed_travel', 'ScuNET',
#                          'stable-diffusion-webui-images-browser',
#                          'sd-webui-controlnet', 'a1111-sd-webui-lycoris',
#                          'LDSR', 'Lora', 'sd-webui-model-converter',
#                          'sd-extension-system-info', 'clip-interrogator-ext',
#                          'sd-extension-steps-animation',
#                          'sd-extension-aesthetic-scorer',
#                          'prompt-bracket-checker',
#                          'multidiffusion-upscaler-for-automatic1111',
#                          'sd-dynamic-thresholding', 'SwinIR',
#                          'stable-diffusion-webui-rembg']
# 02:33:16-589123 INFO     Extensions enabled: []
# 02:33:16-590958 INFO     Running extension preloading
# 02:33:16-592611 INFO     Server arguments: ['--no-hashing', '--share',
#                          '--noupdate', '--skip-extensions', '--gradio-auth',
#                          'login:pass', '--ckpt',
#                          '/content/models/7th_anime_v3_A.safetensors']
# Unloading xFormers
# Available models: /content/automatic/models/Stable-diffusion 1
# Module load:
# /content/automatic/extensions-builtin/clip-interrogator-ext/scripts/clip_interro
# gator_ext.py: ModuleNotFoundError
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/automatic/modules/script_loading.py:10 in load_module               │
# │                                                                              │
# │    9 │   try:                                                                │
# │ ❱ 10 │   │   module_spec.loader.exec_module(module)                          │
# │   11 │   except Exception as e:                                              │
# │ in exec_module:850                                                           │
# │ in _call_with_frames_removed:228                                             │
# │                                                                              │
# │ /content/automatic/extensions-builtin/clip-interrogator-ext/scripts/clip_int │
# │ errogator_ext.py:9 in <module>                                               │
# │                                                                              │
# │     8                                                                        │
# │ ❱   9 import clip_interrogator                                               │
# │    10 from clip_interrogator import Config, Interrogator                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'clip_interrogator'
# ControlNet v1.1.112
# ControlNet v1.1.112
# Module load:
# /content/automatic/extensions-builtin/stable-diffusion-webui-rembg/scripts/postp
# rocessing_rembg.py: ModuleNotFoundError
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/automatic/modules/script_loading.py:10 in load_module               │
# │                                                                              │
# │    9 │   try:                                                                │
# │ ❱ 10 │   │   module_spec.loader.exec_module(module)                          │
# │   11 │   except Exception as e:                                              │
# │ in exec_module:850                                                           │
# │ in _call_with_frames_removed:228                                             │
# │                                                                              │
# │ /content/automatic/extensions-builtin/stable-diffusion-webui-rembg/scripts/p │
# │ ostprocessing_rembg.py:5 in <module>                                         │
# │                                                                              │
# │    4 from modules.ui_components import FormRow                               │
# │ ❱  5 import rembg                                                            │
# │    6                                                                         │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'rembg'
# Loading theme: black-orange
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://8b96669168ed407cad.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# Initializing middleware
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
# Loading weights: /content/models/7th_anime_v3_A.safetensors ━━━━━━ 0.0/4… -:--:…
#                                                                    GB
# Creating model from config: /content/automatic/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Applying scaled dot product cross attention optimization
# Embeddings loaded:  (0)
# Model loaded in 16.5s (load=1.3s create=0.8s apply=12.4s vae=1.3s move=0.6s
# embeddings=0.1s)
# Startup time: 41.0s (torch=6.9s gradio=3.5s libraries=1.2s codeformer=0.2s
# scripts=2.2s ui=3.1s start=7.0s scripts app_started_callback=0.1s
# checkpoint=16.6s)
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/aspectRatioOverlay.js?1682561168.9866934 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=script.js?1682561169.0046952 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/dragdrop.js?1682561168.9876935 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/contextMenus.js?1682561168.9876935 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/edit-attention.js?1682561168.9876935 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/extraNetworks.js?1682561168.9876935 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/extensions.js?1682561168.9876935 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/hints.js?1682561168.991694 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/generationParams.js?1682561168.9876935 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/imageParams.js?1682561168.991694 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/notification.js?1682561168.991694 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/hires_fix.js?1682561168.991694 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/imageMaskFix.js?1682561168.991694 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/localization.js?1682561168.991694 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/imageviewer.js?1682561168.991694 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=extensions-builtin/stable-diffusion-webui-images-browser/style.css?1682562307.645035 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=extensions-builtin/sd-webui-controlnet/javascript/hints.js?1682562307.400011 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=extensions-builtin/sd-extension-system-info/javascript/system-info.js?1682562307.284 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/progressbar.js?1682561168.991694 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=style.css?1682561169.0056953 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/black-orange.css?1682561168.9866934 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=extensions-builtin/stable-diffusion-webui-images-browser/javascript/image_browser.js?1682562307.644035 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=extensions-builtin/multidiffusion-upscaler-for-automatic1111/javascript/bboxHint.js?1682562307.1669884 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=extensions-builtin/prompt-bracket-checker/javascript/prompt-bracket-checker.js?1682561168.9856932 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/textualInversion.js?1682561168.991694 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# API error: GET: https://8b96669168ed407cad.gradio.live/file=javascript/ui.js?1682561168.991694 {'error': 'HTTPException', 'detail': 'Not authenticated', 'body': '', 'errors': ''}
# Progress 1.36it/s ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:07
# Progress 6.24it/s ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:01
# Progress 4.05it/s ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:02
# Downloading: "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth" to /content/automatic/models/RealESRGAN/RealESRGAN_x4plus.pth
#
# 100% 63.9M/63.9M [00:02<00:00, 24.0MB/s]
# 	Tile 1/15
# 	Tile 2/15
# 	Tile 3/15
# 	Tile 4/15
# 	Tile 5/15
# 	Tile 6/15
# 	Tile 7/15
# 	Tile 8/15
# 	Tile 9/15
# 	Tile 10/15
# 	Tile 11/15
# 	Tile 12/15
# 	Tile 13/15
# 	Tile 14/15
# 	Tile 15/15
# Running DDIM Sampling with 9 timesteps
# Decoding image: 100% 9/9 [00:17<00:00,  1.95s/it]
# Progress 3.87it/s ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:02
# 	Tile 1/15
# 	Tile 2/15
# 	Tile 3/15
# 	Tile 4/15
# 	Tile 5/15
# 	Tile 6/15
# 	Tile 7/15
# 	Tile 8/15
# 	Tile 9/15
# 	Tile 10/15
# 	Tile 11/15
# 	Tile 12/15
# 	Tile 13/15
# 	Tile 14/15
# 	Tile 15/15
# Running DDIM Sampling with 9 timesteps
# Decoding image: 100% 9/9 [00:18<00:00,  2.01s/it]
# Progress 3.88it/s ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:02
# 	Tile 1/15
# 	Tile 2/15
# 	Tile 3/15
# 	Tile 4/15
# 	Tile 5/15
# 	Tile 6/15
# 	Tile 7/15
# 	Tile 8/15
# 	Tile 9/15
# 	Tile 10/15
# 	Tile 11/15
# 	Tile 12/15
# 	Tile 13/15
# 	Tile 14/15
# 	Tile 15/15
# Running DDIM Sampling with 9 timesteps
# Decoding image: 100% 9/9 [00:18<00:00,  2.04s/it]
# Progress 3.84it/s ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:02
# 	Tile 1/15
# 	Tile 2/15
# 	Tile 3/15
# 	Tile 4/15
# 	Tile 5/15
# 	Tile 6/15
# 	Tile 7/15
# 	Tile 8/15
# 	Tile 9/15
# 	Tile 10/15
# 	Tile 11/15
# 	Tile 12/15
# 	Tile 13/15
# 	Tile 14/15
# 	Tile 15/15
# Running DDIM Sampling with 9 timesteps
# Decoding image: 100% 9/9 [00:18<00:00,  2.09s/it]
# Progress 3.97it/s ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:02
# 	Tile 1/15
# 	Tile 2/15
# 	Tile 3/15
# 	Tile 4/15
# 	Tile 5/15
# 	Tile 6/15
# 	Tile 7/15
# 	Tile 8/15
# 	Tile 9/15
# 	Tile 10/15
# 	Tile 11/15
# 	Tile 12/15
# 	Tile 13/15
# 	Tile 14/15
# 	Tile 15/15
# Running DDIM Sampling with 9 timesteps
# Decoding image: 100% 9/9 [00:18<00:00,  2.03s/it]
# 100% 20/20 [00:04<00:00,  4.02it/s]
# 	Tile 1/15
# 	Tile 2/15
# 	Tile 3/15
# 	Tile 4/15
# 	Tile 5/15
# 	Tile 6/15
# 	Tile 7/15
# 	Tile 8/15
# 	Tile 9/15
# 	Tile 10/15
# 	Tile 11/15
# 	Tile 12/15
# 	Tile 13/15
# 	Tile 14/15
# 	Tile 15/15
# 100% 10/10 [00:20<00:00,  2.09s/it]
# Progress 3.97it/s ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:05
# 	Tile 1/15
# 	Tile 2/15
# 	Tile 3/15
# 	Tile 4/15
# 	Tile 5/15
# 	Tile 6/15
# 	Tile 7/15
# 	Tile 8/15
# 	Tile 9/15
# 	Tile 10/15
# 	Tile 11/15
# 	Tile 12/15
# 	Tile 13/15
# 	Tile 14/15
# 	Tile 15/15
# Running DDIM Sampling with 9 timesteps
# Decoding image: 100% 9/9 [00:18<00:00,  2.08s/it]
# Progress 3.98it/s ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:05
